# %%
#導入
import pandas as pd

html = pd.read_html("https://todo-ran.com/t/kiji/11430")#html取得
html = html[2]#ページ抜き出し

#整理
html.columns = ["1","都道府県","軒数","人口１０万人当たり","5"]#列名変更
html = html.drop(["1","5"],axis=1)#不要な列を削除

html.to_excel("unicro.xlsx")#エクセルファイルに保存

# %%
#HTML取得

# %%
html
# Out:
#                      都道府県                     軒数              人口１０万人当たり
# 0                     群馬県                    19軒                  0.96軒
# 1                     宮崎県                    10軒                  0.90軒
# 2                     大阪府                    75軒                  0.85軒
# 3                     東京都                   110軒                  0.82軒
# 4                     大分県                     9軒                  0.77軒
# 5                     京都府                    20軒                  0.77軒
# 6                    神奈川県                    66軒                  0.73軒
# 7                     愛媛県                    10軒                  0.72軒
# 8                     山口県                    10軒                  0.71軒
# 9                     山形県                     8軒                  0.71軒
# 10                    栃木県                    14軒                  0.71軒
# 11                    滋賀県                    10軒                  0.71軒
# ...
